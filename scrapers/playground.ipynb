# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import os

# %%
df = pd.read_csv(os.path.dirname(os.getcwd())+"/data/raw/tietoevryBlogsFinal.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           0
# 2             2           0
# 3             3           0
# 4             4           0
#
#                                                 name  \
# 0  Shangqianzi Teng: A passionate advocate for di...
# 1  Accelerating sustainability ambitions at Tieto...
# 2  Mentorship is a catalyst for uplifting diversi...
# 3  Unleash the power of interactivity, payment fl...
# 4  Introducing BLE Audio: unveiling the future of...
#
#                                                 link  \
# 0    /en/blog/2023/09/career-story-shangqianzi-teng/
# 1  /en/blog/2023/09/accelerating-sustainability-a...
# 2  /en/blog/2023/09/mentorship-is-a-catalyst-for-...
# 3  /en/blog/2023/09/Unleash-the-power-of-interact...
# 4  /en/blog/2023/08/introducing-ble-audio-unveili...
#
#                                               others  \
# 0     Meet our people / Shangqianzi Teng / 19.9.2023
# 1  Sustainability / Ida Bohman Steenberg / 19.9.2023
# 2        Meet our people / Ahmad Qureshi / 18.9.2023
# 3       Digitalization / Pernilla Hurtig / 15.9.2023
# 4                Data / Ladislav Podivin / 29.8.2023
#
#                                                 text                  author  \
# 0  With a passion for technology and a master's d...       Shangqianzi Teng
# 1  Congratulations on the new role! What sustaina...   Ida Bohman Steenberg
# 2  After living my early years in Pakistan, I spe...          Ahmad Qureshi
# 3  Just think back 10 years - payments and invoic...        Pernilla Hurtig
# 4  Why is BLE Audio capturing our attention? At T...       Ladislav Podivin
#
#            category        date
# 0  Meet our people    19.9.2023
# 1   Sustainability    19.9.2023
# 2  Meet our people    18.9.2023
# 3   Digitalization    15.9.2023
# 4             Data    29.8.2023

# %%
for idx, row in df.iterrows():
    name = row["name"]
    link = row["link"]
    URL = "https://www.tietoevry.com"+link
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")

    a_list = soup.find("div", class_="contentArea").findChildren(recursive=False)
    # pattern = r'[!@#$%^&*()_+={}\[\]:;"\'<>,.?/\|\\]'

    # # Use the re.sub() function to replace matched characters with an empty string
    # cleaned_name = re.sub(pattern, '', name)

    # # Remove spaces by replacing them with an empty string
    # cleaned_name = cleaned_name.replace(' ', '')
        
    frag = link.split("/")
    final_name = frag[5]
    
    filename = f"E:/Group1FuturiceDSP/tietoevrytexts/{final_name}.txt"
    with open(filename,"w",encoding = "utf-8") as file:

        for elem in a_list:
            
            file.write(elem.text.strip()+'\n')

    print(final_name+" Done")
# Out:
# ShangqianziTengApassionateadvocatefordiversityandgenderbalanceinthetechindustry Done
# AcceleratingsustainabilityambitionsatTietoevry Done
# Mentorshipisacatalystforupliftingdiversityandinclusion Done
# Unleashthepowerofinteractivitypaymentflexibilityandrelevantcommunication Done
# IntroducingBLEAudiounveilingthefutureofWirelessAudio Done
# LeveragingAIforsmartsupplychainfinancedecisions Done
# Howtomakeuseoftheimplementationprojectingrowingnewtalent Done
# Theroleadomesticcloudsolutioncanplayindigitaltrust Done
# EveryoneisaskingthesamequestionHowshouldAIberegulated Done
# ShashiPrabhaSinghAtrailblazingtechnologistdrivinginnovationanddiversity Done
# MarynaTirshuAtalentedfemaleleadermakingwavesinthetechindustry Done
# Modernplatformsempowernewperspectivestomanageenterprisefinancialperformance Done
# Matter-fromaspecificationtoviableSmartHomeproducts Done
# Finnishindustrylookstowardsdata-drivengreengrowth Done
# DataasanEnablerpart3Bringingclaritytodatachaoswithadatacatalog Done
# HowcanartificialintelligenceimproveFinland’shealthcaresystem Done
# GoinggoinggoneWhybanksmustmovetomoderncardandretailpaymentssystemsasap Done
# Doyouwanttobeafossilortrailblazerinthefutureofenergy Done
# TheEU’sDORAwillenhancecollaborationbetweenfinancialinstitutionsandtheirsuppliers Done
# DrivingsustainabilitythroughtechnologyLessonsfromAlmedalen2023 Done
# UnlockingthevalueofyourdataAguidetosuccessfulAPImonetization Done
# BossI’mBackLenaSvenssonSolutionConsultant Done
# Fivewayscardsandphonescanworktogethertomakepaymentsbetter Done
# Don’tbelievethehypecardsstillmatter Done
# ItpaysofftochooseanSAPS4HANAassessment Done
# BestpracticestohouseyourLearningCataloginWorkday Done
# WerneriTuompoThere’smorethanonewayintotheITindustry Done
# HowDigitalCommerceServesasanIcebreakerforDigitalTransformationatIndustrialCompanies Done
# Nobodyknowsyoureadog-30yearslater Done
# AtTietoevrywebelieveinthepowerofeffectivetrainingandcontinuousdevelopment Done
# Google’supdatesinGenAI–keytakeawaysfromFutureofGenAIeventinFinland Done
# StrategicForesightHowwillEUregulatoryimpactResponsibleAIDataandCloudstrategies Done
# Howtonotbuildresilientsystems Done
# Howcanthepaperindustrydriveglobalgrowthandprofitabilitywhilecreatingasustainablefuture Done
# LukasBardProtectingbusinessesandsocietiesmakeseachdaypurposeful Done
# MattiasandEliasUsingAIandmachinelearningtocombatbullying Done
# ChatGPTandDeepfakes Done
# Fromhumanitiestoanengineerinatechnicalfield Done
# WhyBanksMustActNowToBenefitFromReal-TimePayments Done
# Howdoesthecustomerportalsupportinternalsalesefficiency Done
# HowtodriveresponsibleAIadoptioninthefintechindustry Done
# MajaLegernæsLovingthecombinationofworkingwithhardandsoftskills Done
# ToneJensenAstarwholet’sothersshine Done
# ChatGPTandbeyondWhatistheimpactofgenerativeAIoninformationwork Done
# TietoevryBanking’ssolutionshelpbankstostaycompetitive Done
# WillthefuturebecardorphonepaymentsWhytheanswercouldbeboth Done
# SomesaypaymentcardsareyesterdayButtheycouldbekeytothefuture… Done
# WhycelebratingPrideissoimportant Done
# BossImBackKrystianMargasServiceDeliveryManager Done
# HighlightsofWorkday2023Release1 Done
# EmbracingtheCloudConqueringyourFearoftheUnknown Done
# Explorethepathtodigitalsovereignty Done
# BossImBackRiikkaSäikkäläMarketingDesigner Done
# HigherdemandsforsustainabilityinformationinnewEUregulation Done
# DefiningtheAinRPA Done
# IndustrialMetaverseXRexpertHelmutKrämerinaninterview Done
# MakingbillpaymentsmorerewardingwithRequest-to-Pay Done
# Levelupyourfinancialplanning Done
# Real-timecustomerdataisthekeytounlockingbusinessgrowth Done
# BossI’mBackDavidDastgheibSoftwareDeveloper Done
# AreyoufacingERPcloudificationDon’tmisstheopportunitytotakeasignificantstepinyourdigitaltransformation Done
# SHE2023Highlightingthebenefitsofdiversity Done
# JonasLindellStayingoncloudnine Done
# TietoevryAaltoUniversityandUniversityofTurkuhelpingthebankingandinsuranceindustrytocomplywiththeupcomingAIregulation Done
# Today’seconomyneedsnewpaymentservicesforSMEs–here’swhy Done
# Wemustrethinkthewaywetalkabouttechnology Done
# BossI’mBackLāsmaAvotiņa-ŽaglovaProjectManager Done
# HowcanDataPlatformimproveCustomerInsights Done
# UsePeppoltobeaforerunnerinReal-time-economy Done
# AanchalChopraBuildinganagilefutureonallfronts Done
# PausepivotandfindthevaluableusecaselearningsfromAllstate’sconversationalAIjourney Done
# Areyoursystemintegrationssecuregovernedandfuture-proof Done
# TietoevryTechTalksunwrappedthetrendsof2023digitalsovereigntyandthefutureofcloudservices Done
# Yourbesttalentattractsthebestapplicants Done
# Fromfactoriestoanetworkofknowledgehubs–Theeternalevolution Done
# ChatGPTandmygrandfather Done
# SamiAlitaloAsoftwaredevelopershininginthecloud Done
# Howdowesmartlybuildavalue-creatingcustomerportal Done
# Howtodevelopethicaltechnology Done
# Whyassessingmaturityisimportantwhenoutsourcingcybersecurity Done
# EdgeComputing’sRoleinDigitalTransformation Done
# TheVirtuesofVirtualAccounts Done
# Howdataishelpingsolvethebiggestenvironmentalchallenges Done
# FocusonanalysisandactionswithWorkdayFinance Done
# MaaritPaananenProblem-solverandcoachtothemax Done
# Theimportanceofcarefullyselectingtherightfunctionalityforvaluecreationwhenbuildingthecustomerportal Done
# Leadingcompaniescreatingecosystemsaimedatnewbusiness Done
# Harnessingdataforeffectivehealthcare Done
# OpenRANintegrationchallengesnowandintothefuture Done
# Willrobotsoverrulecustomerrelationshipsforfundinvestors Done
# TheValueofSAPCloudALM Done
# Virtualcardstheperfectfitfordigitalnatives Done
# Ambitionsonseveralfronts Done
# Towardsadigitallysovereigntomorrow Done
# Thecustomerportalishotterthanever Done
# TietoevryandT-ranklaunchNordicsolutionforidentifyingbeneficialowners Done
# ChatGPTwillchangeworkfasterthanexpected Done
# TimetotapintothepotentialofPublicCloud–whattoconsiderinthedeploymentandapplicationarchitecture Done
# NordicBanking2023ChallengeAndOpportunityInChangingTimes Done
# WhySecurityOperationsCentershouldbethefirstandlastyouhaveinplace Done
# TietoevryatCES2023itisallaboutsoftware Done
# ESG–Thebiggestchangeagendaofthedecaderequiresdatamanagementcapabilitiestoscale Done
# DigitalHRInsightsCommunity Done
# Cybersecurityis‘goingleft’in2023 Done
# Powerthroughthechallengesofmovingyourpaymentstocloud Done
# Techpredictionsfor2023 Done
# RiskManagementandClientMoneyBalancingtheTwo Done
# VisibilityandControlforCorporates Done
# AutomationofAccountsReceivables–aStepTooFar Done
# HowIoTcanenableyourdigitaltransformation–3tipstosucceed Done
# TietoevryCareecosystemcollectsenterpriseswithdifferentcompetenciestogethertorealizesharedgoals Done
# Datalakesandwarehousespart5Handsonsolutions Done
# Employeeskillsdataarethedigitalcurrencyforbusinessgrowthdata-drivendecisions Done
# Beingagoodparentrequiresflexibility Done
# Flexiblesustainablesecurewhyvirtualcardsmakesenseforall Done
# IdentityDrivenSecurityServiceembeddedidentitysolutionsdeliveredasAPIs Done
# Don’tripandreplaceorhowaSaaSsolutionallowsflexibilitywhenoutsourcing Done
# Cloudservices–athreatoropportunity Done
# OndatavaluewithSAPdata Done
# DataasanEnablerpart2Areyouignoring80ofyourdataassets Done
# 3factstoconsiderwhenevaluatingSaaSmodelforpaymentsprocessing Done
# Acquirecustomersincost-efficientwaywithTopUpRecommender Done
# MakinganimpactfulchangewithDEI Done
# TeppoValkamaDancingthroughthechallengesofleadership Done
# SAPCloudfromthegroundup Done
# ABusinessapproachinProjectManagement Done
# ReflectionsonSlush2022 Done
# SovereigncloudstandsoutasamajortrendatVMwareExploreEurope2022 Done
# Theimportanceofseeingthebigpictureinthedata-drivendigitaltransformationjourneyPart2 Done
# Theimportanceofseeingthebigpictureinthedata-drivendigitaltransformationjourneyPart1 Done
# WhatsetsSaaSapartfromon-premandprocessingcentresolutionsinthepaymentsspace Done
# Maximizeyourcloudinvestmentsbyimprovingyourdevelopersexperience Done
# Eveninenergymanagementlittlestreamsmakebigrivers Done
# Towardsacleanerandmoreintelligentenergysystem Done
# WorkdayPeakonEmployeeVoiceWhybusinessesthrivewhenemployeesareheard Done
# The’newnormal’incybersecurity–oristhereoneyet Done
# 3reasonstobringyourpaymentapplicationtoPublicCloud Done
# City’ssmartnessismeasuredininhabitantsatisfaction Done
# Digitalresiliency Done
# Brownfieldapproach–Yourquickandcost-efficientconversiontoSAPS4HANA Done
# DataasanEnablerpart1Findingthepurposefordata Done
# Hybridworkandthewayforward Done
# HowArtificialIntelligencecanimprovecybersecurityinindustrialMachineLearningandIoTapplications Done
# CareerjumpmadeeasywithTietoevryConnectAcademy Done
# CustomercommunicationsdonotbelonginERP Done
# Startingalarge-scaleITprojectwithDevOpsReadthisfirst Done
# InvisiblecashCanvirtualcashmanagementfullysolvethecorporatecashvisibilityquestion Done
# TransatlanticdataflowinasafesecuremannerbetweenEUandUSisnowbecomingareality Done
# WhyeverySAPS4HANAtransformationprojectneedsaprocessminingsolution–SAPS4HANAVectorial Done
# Digitalizeforfutureenergyindustrysuccess Done
# Documentation-theblindspotofintegrationandAPIdevelopment Done
# 10thingsyouneedtodotopreventcyberattacks Done
# ReflectionsonmobiledevelopmentwithReactNative Done
# Areyourcyberrisksandpreparednesscommensurate Done
# Thedeveloperdebatersguidetothinkingonyourfeet Done
# ThefivemostcommonUXdesignmistakesandhowtoavoidmakingthem Done
# Theimportanceofmakingsustainablechoicesinallaspectsoflife Done
# AdvancingTrust-BasedDigitalSocieties Done
# AchievesalestargetinmostprofitablewaywithSalesOptimizer Done
# AnindustrialITsolutionthatpaysitselfbackinoneshift–factorfiction Done
# Whydigitalsovereigntyisincreasinglyimportant Done
# WhentoapplyIntegrationRPAandIntelligentAutomationinthetransformationjourney Done
# WhydoessynchronizedIntegrationRPAandIntelligentAutomationIRIAneedtoworktogether Done
# ServitizationinmanufacturingdemystifiedLearningsfromgrowingservicebusiness Done
# “Ihave“a-ha”momentseveryday” Done
# “Workingwithchangeattheinterfacebetweentechnologyandhumanityisarealprivilege” Done
# Ilikesolvingproblemsusingtechnology Done
# ThenumberoftheriskCEO–haveyoucalibratedyoursecurityinvestmentswithyourbusinessrisks Done
# Howmicromerchantsareadaptingtothecashlessworld Done
# TransformingfromindustrialautomationtoAIbasedautonomyisProjectBonsaitherightfitforyou Done
# TheiT’sTissue2022eventwasimmenselyuseful–whilerevealingabusinesssuccessgap Done
# 4keytrendsthatwillimpactyourfutureDigitalWorkplace Done
# TietoevryBankingdrivingcollaborativeRDprogramsintheVeturiecosystemproject Done
# Tapintothepowerofmobiledevices Done
# Optimisingtheloanoriginationprocess-importantaspects Done
# Datalakesandwarehousespart4Challenges Done
# APImanagement–akeytoeffectivebankingservices Done
# OptimiseyourIToperationswithAIOps Done
# Frictionisn’tbad Done
# AIOpslowriskhighrewardButit’snomagicbullet Done
# WhenUXmeetsCX Done
# ModernpaymentsusetoomuchenergyHere’showwecandobetter Done
# Publiccloudsecurityinturmoil Done
# HenriVäisänenHappythataseniordeveloperhadnotedmyefforts Done
# AtTietoevrytheonlythingrequiredisahungertolearn Done
# APIintegration–thekeytohappycitiesandhappypeople Done
# ArtificialIntelligenceguidesroutingandencouragesteamworkatPosti Done
# IntelligentCustomerExperiencedrivesdigitalfutures Done
# 4usecaseswherenon-bankfinancialinstitutionscanleveragevirtualaccounts Done
# Tissuedemandisgrowingdoyouwantasliceofthemarket Done
# Agiledigitalleapstowardsmoreefficientdatauseinaglobalcompany Done
# SecurityisparamountwhenmigratingyourSAPintothePublicCloud Done
# Securityawarenesstoresistsocialengineering Done
# Energymarketstillinconstantfluxdigitalizinghelpsadaptation Done
# GuestblogDigitalizationjourneyintheFormula1world Done
# UnlocknewrevenuebypersonalizingyourcustomerapproachwithAIrecommendersystems Done
# Aremothersthesolutiontoourtechproblem Done
# “Goodmasterdataisessentialforcompanymanagement” Done
# AhelpinghandforHCMCloudprojectcustomersiderolesstaffing Done
# HowwegetmorewomentochooseacareerinITandcybersecurity Done
# SHEtalkGuroStorlienEvensenonhowself-leadershipcanchangediversityintech Done
# SHEtalkAnetteBruråscallsforanincreaseinwomeninmanagementpositions Done
# CashPooling–crackingtheliquiditypuzzle Done
# Archivingdatapart2Sixtipsforassessingdataformeaningfularchiving Done
# PodcastHowdoesdatafitintotheCIOroleKristiinaLammilafromAhlstrom-Munksjö Done
# ModularEnterprisecreatesprofoundagility Done
# ConnectingtheCloud-NativeEnterpriseEdgewithoutCompromisingPerformance Done
# AjourneytowardanagileandDevOpswayofworkingcultureandtoolsinsoftwaremaintenance Done
# Activityplanningforafter-schoolclubs–anewapproach Done
# Datamanagementinfocus-createadatausecaseandputthebackboneinplace Done
# Archivingdatapart1Decommissioninglegacyapplicationswithcloud Done
# Timetobenefitfromadatastrategy Done
# Datasovereigntyandopportunitiesinthedataeconomy Done
# Essentialroleofpaymentsystemsinthepaymentscontingency Done
# “Useaseasytoolsasyoucan”–ICAGruppenhasashareddatatoolboxbutdistributedprojectownership Done
# HowtoNavigatetheFintechForest Done
# Changingtimesinmanufacturing Done
# MoveyourSAPsolutionstothecloudwithRISEwithSAP Done
# Sustainabilitywhythecardbusinessmustact Done
# PodcastBringdataownershipclosertoretailbusinesslines–OlofGranbergICAGruppen Done
# 4tipsforsuccessfulAIdevelopmentinhealthcare Done
# DoyouhaveaCloudstrategybutarestuck Done
# Sixareaswherecloudprovidesbusinesseslargegains Done
# Boostcustomerservicewithcloud Done
# PodcastHowdoAIapplicationsimprovehealthcareatHUSHelsinkiUniversityHospital Done
# Ahumanistwhoheartsmachines–what’smycodeforsuccess Done
# KeyOpenRANintegrationchallenges Done
# Theimportanceofbalancingchange–meetTheCognitiveEnterprise Done
# Whyisdiversitycrucialfortech Done
# ThecontingencyofpaymentsintheNordiccontext–ShelteredHarborasapotentialsolution Done
# Byebyeopenbanking–welcomeopenfinance Done
# Buildingafuture-proofdatafoundationUnleashthepowerofself-serviceanalytics” Done
# Thetechsectorneedsmorewomen–changewillonlycomewithdeterminationandconcreteactions Done
# PodcastNewcloudcapabilitiesmeetestablishedplatformsatScandinavianAirlines Done
# TheperfectmixWorkingonpassionprojectsandsupportedtocontinuallydevelop Done
# ERPArchitecture–2fundamentalcornerstonesand4architypestoserveyourbusiness Done
# WillpubliccloudmakeSAPagile Done
# TimetochangeyourperceptionofMainframeandlearnhowitconnectstothecloud Done
# DatamanagementtransformationFromdefensivetooffensivebusiness-drivendatause Done
# PodcastHowtocreateasuccessfuldatastrategy–notjustacoffeetablebookLearningsfromJohnBottegaEDMCouncil Done
# Bankingandfinancialservicesreinvented Done
# Workdayinpractice–HowIusedWorkdaywithintheHROperations Done
# TalentmarketpredictionsWhattoexpectfrom2022 Done
# ComparisonofSAPS4HANAsolutions Done
# Corporatecashmanagementtrendsin2022 Done
# Corporatetreasuryjourney–Fromautomationofpayablesandreceivablestoin-housebanks Done
# DevOpsbreaksdownsilosandincreasesproductivity Done
# WhyAIalonecan’treleasethefullvalueofyourbusiness Done
# Cybersecurityin2022DonotfeartoLiftthelidoffthecanofworms Done
# Thetrendsandhappeningsourexpertsforseein2022andtheiradviseonhowtogoaboutit Done
# Isyourcustomerinteractiononparwithexpectations Done
# “Toolongandtoomuchhavedatabeenseenasanecessaryeviltogetaspecificprocessdone” Done
# ThekeytorecoveryStrategicworkforceplanning Done
# WhyusecloudbackupwhenmydataisalreadyintheCloud Done
# Continuouslearningsecuresthefutureofourcompanyandourpeople Done
# Timetoputsustainabilityattheheartofyouroperations Done
# FromProductionEngineertohands-onDataScientistinhealthcaretechnology Done
# Howcloudbackupcansupportyourbusinesswhenworkingremote Done
# Thebiggerthecompanythebiggertheimpact Done
# Timetogetupandrunningfastonacloudplatform Done
# OffshoringItsnotjustaboutlowcosts Done
# WhattoexpectfromyourITpartner Done
# PMCHydraulics’successfultransformationtoacloudERP Done
# 7criteriaforbuildingasuccessfulcentralpaymentsinfrastructureforreal-timepayments Done
# PreparefortheevolutionofNext-Genservices Done
# S4HANAauthorizations–validatetheoldbringinthenew Done
# Puttingtrusttothetest–Tietoevryemployeeschoosehybridwork Done
# RPASolutionsforSAPSuccessFactors Done
# NewreportPhishingcasesincreasedby400percentduringthepandemic Done
# TimetogetthefullbenefitsofutilizingthePublicCloudasanSAPplatform Done
# 5tipsforasecureonlineshoppingexperience Done
# CloudsecurityABCpartII-Howtohidefromhackers Done
# Allthegoodstuffisstayingthesamebutthereisanewproductname Done
# Thebumpyroadtowardsasoftware-definedvehicle Done
# Timetoredefinedatamanagementincloud Done
# ApositiveenvironmentgreatcolleaguesandexcitingopportunitiesmademereturntoTietoevry Done
# HappyteamsatDNAandTietoEVRY Done
# HowWorkdayhelpsustodriveagilityandscaleafterthemerger Done
# Whysovereigncloudisahottopic–5tipsandthebackground Done
# TimetonavigatethedataregulationandEuropeansovereigncloud Done
# GoField–ThethreemostimportantstepstowardsSAPS4HANA Done
# CardversusSuper-Appwhichonewins Done
# MakingtheLeapFromDevelopertoTestAutomationSpecialist Done
# CybersecurityAwarenessMonth2021isoverbuttheworkcontinues Done
# HeadlessSAP–Apracticalguidetothearchitecture Done
# Datalakesandwarehousespart3AzureSynapsepointofview Done
# TimetogetupdatedonCLOUDActSchremsIIGaia-Xanddatasovereigntyregulations Done
# PodCastScalableEdgeComputingReferencePlatform Done
# SIAM-TheFifthPillar Done
# ThepassionforIFSmadeDamithJinasenatakealeapfromSriLankatoSweden Done
# AIthegatewaytosuccessfulchurnpreventionandcustomerretention Done
# SAPsecurityonthepubliccloud–thesamebutdifferent Done
# Timetomakeyourintegrationstrategyabusinessstrategy Done
# ChangingPlatformsReinventingcreditcardsforthedigitalera Done
# Isanopen-source-basedsolutionviableforedgecomputingdeployments Done
# Diversitydrivesequalityindigitalservices Done
# TimetotalkaboutcloudsecuritypartI Done
# Howtogettruesecurity–amodernSOCrespondstomodernthreats Done
# AreyoureadyfortheevolutionofNext-GenEnterpriseServices Done
# BringDataOpstolifewiththehelpofdatawarehouseautomation Done
# CyberSecurityAwarenessMonth2021ison–anditiseveryone’sbusiness Done
# Reinventingcardplatformsduringbanking’sradicalchange Done
# TietoEVRYcontinuestodelivermarketleadingfraudpreventionandcustomerexperiences Done
# Takingthecloud-nativeapproachintotheDNAoftelecomapplicationandinfrastructuredevelopment Done
# Governmenttocitizenpayments–isittimetoswitchtoreal-timetransactions Done
# Human-centricapproachforahumanecause Done
# WorkdayImplementationsFivepostgo-liveconsiderations Done
# Howclosearewetourbanautomateddriving Done
# Datalakesandwarehousespart2DatabricksandSnowflake Done
# SIAMDeliveringvalueinmultisourceenvironment Done
# Timetomodernizetocloud Done
# Theracetodigitalwhybanksmustrationalisetheircardplatforms Done
# What’sinitformeTheimplicationsofCentralBankDigitalCurrenciesforeverydayusersandbanks Done
# Whatcanthepaymentsworlddotocutemissions Done
# Bye-byecashWhycentralbanksarepushingdigitalcurrencies Done
# Datalakesandwarehousespart1Introtoparadigms Done
# AwardedAndroidAutomotivecontributionsboostthedevelopmentofaudioandvehicledatamanagement Done
# 4focuspillarsofPSPs Done
# GuestblogGuessWhatWeDon’tHaveaClueAbouttheFutureofPulpPaperandFibre Done
# 3reasonswhyyouneedWorkdayExtendandwheretostart Done
# EmbeddedAIimprovespaperandboardindustrycompetitiveness Done
# Consumerizationleadingenterprises Done
# Timetoputresilienceatthecoreofbusinessstrategy Done
# 5reasonswhysecurityshouldnotbebarriertorunningSAPinthepubliccloud Done
# NewpaymentinfrastructurestoimproveutilitypaymentswithRequesttoPay Done
# Insearchoflowhangingfruitincustomerlifecyclemanagement Done
# Ourhomeswillbeevensmarter–thankstotheMatterstandard Done
# Timetomaketheriskofnewproductintroductionwellcalculated Done
# SuperiorCustomerExperienceisonlyPossiblewithGoodDataTimetoEstablishaDedicatedCustomerDataTeam Done
# Wealthtrends2021AdventoftheUnderserved Done
# Buildinganinclusivecultureneedseveryoneonboard Done
# Atrulyinclusiveworkingcultureisnotcreatedwithhashtagsbutwithconsciouschoices Done
# Nationalpaymentsystemsarepavingthewayforreal-timee-commerceandin-storetransactions Done
# Doesyourcybersecuritystackcoverbothriskandperceivedrisk Done
# JointheDataInsiderscommunity Done
# Digitalizationinpackagingindustries Done
# Whyscalemattersinthecloud Done
# SIAM–WhatisitTheUltimateguidetoServiceIntegrationandManagement Done
# WhatischangingcomparedtotraditionalITservicemanagement Done
# Threewaystohelpyourmid-marketcompanygrow Done
# 4stepsconsiderationstopaymentdigitalization Done
# Upandsidewaysresponsibilityandtrustopeneddoorstomanyroles Done
# BuildingmoreequalandinclusivedigitalsocietywithFindy Done
# TimetobreakdownthesilosforexponentialP2Ppaymentsgrowth Done
# HowwillP27impactthepaymentlandscapeforbusinessesFindoutthenewopportunities Done
# Cloudglossaryfororganizations–thetermsyouneedtoknow Done
# Canyourlendinghistorybecomeacompetitiveadvantageanddriveportfolioprofitability Done
# Whichoneshouldyouchoose-PrivatePublicHybridorMulti-Cloud Done
# PodcastWhyisOpenRANsoimportanttotheMobileIndustry Done
# Timeforapubliccloudstrategy Done
# WhatnextforThePoliteType Done
# 3KeystobenefitfromSecurityOperations Done
# HowdoestheNext-generationSecurityOperationsCenterSOClooklike Done
# KeyinsightsintoIntelligentAutomationintheNordics Done
# WhyeverybodyisinterestedinyourjetwireratioandotherviewsonyourArtificialIntelligencestrategy Done
# TimetomovebeyondlegacyIson-premhostedSaaSorBPObestforyourbank Done
# Howdevelopingmycommunicationskillsmademeabettersolutionarchitect Done
# Technicalrolesneedsoftskills–whyIbecameateamplayeranddiversifiedmyskills Done
# Wealthtrends2021Democratizationofwealth Done
# LearningasaLifestyle-TogetherwithMicrosoft Done
# BiometricsSecuringafutureforpaymentcards Done
# Themorethemerrier Done
# Cloudconsultantarethego-topersonsforbusinesseswhowanttomodernizeforthefuture Done
# TimeforanAPIeconomyandit’schangingeverything Done
# Timetoaccelerateinnovationwithdata Done
# EvolvingimportanceofSIAMduringtimesofaccelerateddigitaltransformation Done
# BreakingdownthebarrierstoAIandMachineLearning Done
# Whatdoesthefutureholdfor“on-us”transactions Done
# Asoftapproachtohardfacts–timetogetaheadwithananalyticsstrategy Done
# Thebenefitsofinvestinginamanagedserviceforfinancialcrimeprevention Done
# Wouldyourathernavigateyourcareerwithoutdatedorupdatedskills Done
# MasterthetermsofdigitaldevelopmentwithourDevOpsandAgileglossary Done
# Agilitywillbekeyforacquirersastheymeetmerchantsneedsfornewinstruments Done
# IsOpenRadioAccessNetworksarevolutionforthewirelessindustry Done
# Timeforsoftware-driventransformationinthefinancialservicesindustry Done
# BestpracticeWorkdaytoSAPintegration Done
# DoyouhavewhatittakestobeanEPIfront-runner Done
# TimetocooperateHowthemunicipalityofHaningekeepsupthepaceofdigitalization Done
# RetailPaymentsareConvergingtoData-RichReal-TimePayments Done
# Timetotakeadvantageofhyperconnectivity-beginyourjourneytoinsightsandinnovationtoday Done
# Humanexperienceisattheheartofcustomerexperienceandfuturebusiness Done
# BiometriccardsupgradeEasierandcheaperthanyouthink Done
# Digitalinequalityisamoreimportantthemethanever Done
# Buildingagilityandbridgingtheskillsgapwiththepowerofone Done
# YearningforlearningMovingfromoneroletoanothermadeeasyatTietoEVRY Done
# Meaningfulworkwithlike-mindedpeople Done
# HeadlessSAP-improvedusabilityandasmoothtransitiontoS4HANA Done
# How5Gaddsvalueinthecorporateworld Done
# Wealthtrends2021Goal-basedinvesting Done
# Isstrongcustomerauthenticationandfrictionlesscardpaymentsacontradiction Done
# Anintelligentbrand-levelcustomerexperience–thenextbattlefieldforcompetitiveness Done
# Thejoyofbeingtoldwhattowearinyournativelanguage Done
# ServiceDesk–teamworkacrossdepartments Done
# Ajourneybegins–ServiceDeskSpecialistinthemaking Done
# Asmoothuserjourneylaysthefoundationforapositivecustomerexperience Done
# Timetobringlostrevenuesbacktothecardsbusiness Done
# Finland’ssocialandhealthcareITsystemsareamongthebestintheworld Done
# Retailin2021–thetechnologytrendsspeedingupdigitaltransformation Done
# Timetodecidewillwaterfallagileordevopsdeliveryournewcardplatform Done
# TietoevrysSustainabilitygameplan2023Upgradingtomorrow Done
# Timetoembracethethirdgenerationofreal-timepayments Done
# Benefitsofkeepingtherightfocuswhenmergingcompanies Done
# Timetocreateadigitalworkplaceforbeyondthepandemic Done
# ArtificialIntelligenceneedshistorydata–don’tdeleteit Done
# Top10trendsimpactingWealthManagementin2021 Done
# TimetoreplaceyourcardpaymentsplatformDon’tdoit Done
# Timetohavealookattheover-the-topplayersintheTelecomindustry Done
# Fromvirtualworldtoreallife Done
# HansKristianmadetheentiresystemfortheDirectorateofFisheriesCloudNative Done
# Hereyougettoworkwithstate-of-the-arttechnology Done
# TimetoenhanceEdgeIoTsecurity–fromdevicestopeopleandprocesses Done
# DigitalizinginvoiceanddocumenttransactionprocessforNorwegianorganizationstosavecostsandtheenvironment Done
# Ownacarsavetheplanet Done
# DoyoufindcardauthenticationaheadacheTimetomakeitapartofthecustomerexperiencethen Done
# There’snotimetobecomplacent Done
# Thetechnologypredictionsyouneedtoknowfor2021 Done
# Timetoembracecustomer-facingAIopportunities Done
# Whensustainabilitymeetsdigitalization–HowLukeincreasestheimpactofwhattheydo Done
# TimeforasecurewaytosupportmerchantsconsumersandIoTpayments Done
# HowNordicbankingisturninginvestmentgreenerandmoresustainablein2021 Done
# Timetoreachcloudbenefitsfasterwithoutdisruptingyourbusiness Done
# TimeforamoreprofitablefutureTimeforadigitalcardexperience Done
# Fiveeasywaystoenhancesecurityforyouronlineconsumers Done
# Towardsamoreequaldigitalsociety Done
# MicrosoftAzuretrainingsbenefitbothourprofessionalsandcustomers Done
# Keepitsimple–enhancecustomerexperienceandengagementwithSAPCX Done
# Cloudcomputingpowersthedataeconomy–ofcoursebuthow Done
# Fromgraduatetoleaderinafewyears Done
# Acompanywhereyoucanflourish Done
# Coronabot—awinnerintheCovid-19pandemic Done
# LeadingateamofseventovictoryinoneofScandinavia’sbiggestHackathonsafterlessthantwoyearsinthejob Done
# Mygraduateexperiencewithamentorforsupportandinclusion Done
# Timeforsoliddatagovernance Done
# Howtoadoptcloudservicessecurely Done
# Robingetshismotivationthroughthedevelopmentofhiscolleagues Done
# Igamedmywaytoagraduateadventure Done
# HowaregulateddebtregisterhelpedreduceNorwegianconsumerdebtby8injustoneyear Done
# Howcangamificationincreasediversity Done
# GraduateProgramprovidesaquickwaytoadapttotheworkculture Done
# Timetoscaleyourcloudinvestment andlevelupyourbusiness Done
# SocialworkandICTcomplementarycouple Done
# CombiningmytechinterestandbusinessexperiencethroughTietoevry’sGraduateProgram Done
# Howdoyoumoveyourenterpriseapplicationstothecloud Done
# CIOmeansCareerIsOverOrMaybenot Done
# TheFundamentalsofCloudDataPlatforms Done
# Divingintounfamiliartechnologiesandindustries-myjourneyasagraduate Done
# Havingbothmyownbuddyandmentorasagraduateispriceless Done
# Cloudifyingpeople’severydaylivesthroughDevOps Done
# Multi-cloudisbecomingthedigitalbackbone Done
# OpenStackdeployment Done
# Fast–secure–frictionlessCanyourdigitalidentityreplacebiometrics Done
# Technologyisthekeytocurbingclimatechange Done
# ActivateandsecureB2Bsalesintimesofchangelearningsfromthemanufacturingsector Done
# Impactingsocietyasagraduatepartofaworld-classteam Done
# FirstP27servicescomingonline–GuideforbanksoperatinginSweden Done
# GoinggreenwithEdgeComputing Done
# OpenStackdeployment–Preparationoftheenvironment Done
# Helpingthecustomersbecomethedigitalchampionoftomorrow Done
# Carbon-neutralcitiesaredatadriven Done
# TimetoanswerthefourmostcommonquestionsaboutCloudTransformation Done
# Onanexpeditiontofuturepossibilities-Graduatejourneykickedoff Done
# WhichdirectionisMicrosofttakingforthecomingyearsReflectionsfromIgnite2020 Done
# Howoutsourcingoflendingadministrationcanboostdigitaltransformationinthebankingindustry Done
# WorkingfromhomeAttackersaretoo Done
# Emergingedgecomputing–unlockthevalueofyourdata Done
# CostcontrolwithDigitalOilfieldChemistry Done
# SometimesexistingDevOpspracticesaren’tenough Done
# KeepUXdesigntopofmindwhenyoumovetoSAPS4HANA Done
# Productionmanagementimprovesqualityandproductivity–buthowdoweachievelarge-scalebenefitsinhealthandsocialcare Done
# TietoEVRYYoungProfessionalsutilizethepowerofnetworkingacrosscountryborders Done
# Aplacewherefuturetalentscanchallengethemselves Done
# Helpingcustomerswiththeircloudjourneyandshapingthefutureofeverydaylife Done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Group1FuturiceDSP\gettingtext.ipynb Cell 3 line 9
#       <a href='vscode-notebook-cell:/e%3A/Group1FuturiceDSP/gettingtext.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> page = requests.get(URL)
#       <a href='vscode-notebook-cell:/e%3A/Group1FuturiceDSP/gettingtext.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> soup = BeautifulSoup(page.content, "html.parser")
# ----> <a href='vscode-notebook-cell:/e%3A/Group1FuturiceDSP/gettingtext.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> a_list = soup.find("div", class_="contentArea").findChildren(recursive=False)
#      <a href='vscode-notebook-cell:/e%3A/Group1FuturiceDSP/gettingtext.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> pattern = r'[!@#$%^&*()_+={}\[\]:;"\'<>,.?/\|\\]'
#      <a href='vscode-notebook-cell:/e%3A/Group1FuturiceDSP/gettingtext.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> # Use the re.sub() function to replace matched characters with an empty string
#
# AttributeError: 'NoneType' object has no attribute 'findChildren'
